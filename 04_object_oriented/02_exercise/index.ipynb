# %% [markdown]
# # PHP

# %% [markdown]
# ## 4. Object-Oriented Programming

# %% [markdown]
# ### 4.2 Exercise

# %% [markdown]
# Implement the below class diagram.

# %%
! plantuml project/diagram.puml -tsvg

# %%
from IPython.display import SVG
SVG(filename='project/diagram.svg')

# %% [markdown]
# You can test your solution using below checks.

# %% [markdown]
# Static analysis:

# %%
! composer global require phpstan/phpstan --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update phpstan/phpstan
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Generating autoload files
# 1 package you are using is looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.
# Using version ^1.10 for phpstan/phpstan

# %%
! ~/.composer/vendor/bin/phpstan analyze --level max project/
# Out:
#   0/10 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0% 10/10 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ ---------------------------------------------------------------------
#   Line   src/App.php
#  ------ ---------------------------------------------------------------------
#   10     Constant SIZE not found.
#          💡 Learn more at https://phpstan.org/user-guide/discovering-symbols
#  ------ ---------------------------------------------------------------------
#
#
#
#  [ERROR] Found 1 error

# %% [markdown]
# Tests:

# %%
import subprocess
phpServer = subprocess.Popen(['php', '-S', 'localhost:8888', '-t', 'project/public'])
# Out:
# [Wed Apr  3 17:51:38 2024] Failed to listen on localhost:8888 (reason: Address already in use)

# %%
! cd tests && composer install && vendor/bin/codecept run
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating autoload files
# 43 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# Codeception PHP Testing Framework v5.1.0 https://stand-with-ukraine.pp.ua
#
# Tests.Acceptance Tests (1) -----------------------------------------------------
# ✔ Test01_ObjectOrientedCest: Test(0.10s)
# --------------------------------------------------------------------------------
# Time: 00:00.278, Memory: 14.00 MB
#
# OK (1 test, 31 assertions)
# [Wed Apr  3 17:51:45 2024] [::1]:53962 Accepted
# [Wed Apr  3 17:51:45 2024] [::1]:53962 [200]: GET /
# [Wed Apr  3 17:51:45 2024] [::1]:53962 Closing

# %%
phpServer.kill()

# %% [markdown]
# Now you can run the IDE:

# %%
! phpstorm project
# Out:
# CompileCommand: exclude com/intellij/openapi/vfs/impl/FilePartNodeRoot.trieDescend bool exclude = true
# 2024-04-03 17:52:06,704 [   2866]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.intellij.ae.database.core.baseEvents.fus.AddStatisticsEventLogListenerTemporary, plugin=com.jetbrains.ae.database)
# 2024-04-03 17:52:06,706 [   2868]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.jetbrains.rdserver.statistics.BackendStatisticsManager, plugin=com.jetbrains.codeWithMe)
# 2024-04-03 17:52:07,690 [   3852]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.search.FilenameIndex initializer requests com.intellij.ide.plugins.PluginUtil instance
# 2024-04-03 17:52:09,422 [   5584]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.lang.javascript.psi.jsdoc.impl.JSDocCustomTags initializer requests com.intellij.lang.javascript.JSDisposable instance
# 2024-04-03 17:52:10,635 [   6797]   WARN - #c.i.o.v.n.p.d.e.DurableEnumeratorFactory - [enumerator.mmapped]: .valueToId map is out-of-sync with .valuesLog data -> rebuilding it
# 2024-04-03 17:52:11,607 [   7769]   WARN - #c.i.s.ComponentManagerImpl - org.zmlx.hg4idea.provider.HgChangeProvider initializer requests com.intellij.openapi.vcs.FileStatusFactory instance
# 2024-04-03 17:52:11,721 [   7883]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.LanguageSubstitutors initializer requests com.intellij.psi.LanguageSubstitutors instance
# 2024-04-03 17:52:15,690 [  11852]   WARN - #c.i.o.a.i.ActionUpdater - 1627 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-04-03 17:52:16,322 [  12484]   WARN - #c.i.o.a.i.ActionUpdater - 585 ms to grab EDT for ToolWindowHeader$2#GetChildren@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-04-03 17:52:16,988 [  13150]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./language-configuration.json` in bundle `/opt/PhpStorm-233.14475.35/plugins/textmate/lib/bundles/mdx`
# 2024-04-03 17:52:17,655 [  13817]   WARN - #c.i.o.p.i.ProjectFrameAllocator - Cannot load project in 10 seconds:
# - BlockingCoroutine{Active} [BlockingEventLoop@7b5710c6]
# 	- "showSplashIfNeeded":StandaloneCoroutine{Completing} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.Default]
# 		- "showSplashIfNeeded":LazyStandaloneCoroutine{Active} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.Default]
# 	- "startApplication":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, startApplication, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.Default]
# 		at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2.invokeSuspend(ProjectFrameAllocator.kt:195)
# 		at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2.invokeSuspend(ProjectFrameAllocator.kt:157)
# 		at com.intellij.openapi.project.impl.ProjectManagerImpl.doOpenAsync(ProjectManagerImpl.kt:635)
# 		at com.intellij.openapi.project.impl.ProjectManagerImpl$openProjectAsync$4.invokeSuspend(ProjectManagerImpl.kt:618)
# 		at com.intellij.openapi.project.impl.ProjectManagerImpl.openProjectAsync(ProjectManagerImpl.kt:617)
# 		at com.intellij.ide.impl.ProjectUtil.openOrImportAsync(ProjectUtil.kt:174)
# 		at com.intellij.ide.CommandLineProcessor.doOpenFileOrProject(CommandLineProcessor.kt:75)
# 		at com.intellij.ide.CommandLineProcessor.openFileOrProject(CommandLineProcessor.kt:517)
# 		at com.intellij.ide.CommandLineProcessor.processOpenFile(CommandLineProcessor.kt:384)
# 		at com.intellij.ide.CommandLineProcessor.processExternalCommandLine(CommandLineProcessor.kt:258)
# 		at com.intellij.idea.IdeStarterKt.loadProjectFromExternalCommandLine(IdeStarter.kt:235)
# 		at com.intellij.idea.IdeStarter.openProjectIfNeeded$suspendImpl(IdeStarter.kt:155)
# 		at com.intellij.idea.IdeStarter$start$2$openProjectBlock$1.invokeSuspend(IdeStarter.kt:75)
# 		at com.intellij.idea.IdeStarter$start$2.invokeSuspend(IdeStarter.kt:82)
# 		at com.intellij.platform.ide.bootstrap.ApplicationLoader$executeApplicationStarter$2.invokeSuspend(ApplicationLoader.kt:282)
# 		at com.intellij.platform.ide.bootstrap.ApplicationLoader.executeApplicationStarter(ApplicationLoader.kt:281)
# 		at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$appLoaded$1$1.invokeSuspend(main.kt:323)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 			at java.base/java.lang.Thread.getStackTrace(Thread.java:1619)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDumpImpl(DebugProbesImpl.kt:336)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDump(DebugProbesImpl.kt:321)
# 			at com.intellij.diagnostic.CoroutineDumperKt.traceToDump(coroutineDumper.kt:305)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:278)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:280)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:280)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:280)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:118)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:53)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines$default(coroutineDumper.kt:45)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2$debugTask$1.invokeSuspend(ProjectFrameAllocator.kt:153)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1.invokeSuspend(ProjectFrameAllocator.kt:312)
# 			- "tool window pane creation":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, tool window pane creation, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$initUi$3.invokeSuspend(ToolWindowSetInitializer.kt:93)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer.initUi(ToolWindowSetInitializer.kt:90)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$doInit$2.invokeSuspend(ToolWindowManagerImpl.kt:522)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.doInit(ToolWindowManagerImpl.kt:505)
# 				at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1$1$1.invokeSuspend(ProjectFrameAllocator.kt:318)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 			at com.intellij.openapi.fileEditor.impl.UiBuilder$processFiles$2.invokeSuspend(EditorsSplitters.kt:981)
# 			at com.intellij.openapi.fileEditor.impl.UiBuilder.process(EditorsSplitters.kt:902)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2$3.invokeSuspend(ProjectFrameAllocator.kt:352)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2.invokeSuspend(ProjectFrameAllocator.kt:351)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt.restoreEditors(ProjectFrameAllocator.kt:335)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1$1.invokeSuspend(ProjectFrameAllocator.kt:183)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1.invokeSuspend(ProjectFrameAllocator.kt:182)
# 			- "editor provider computing":DeferredCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, editor provider computing, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 				at com.intellij.openapi.fileEditor.impl.FileEditorProviderManagerImpl.getProvidersAsync(FileEditorProviderManagerImpl.kt:86)
# 				at com.intellij.openapi.fileEditor.impl.UiBuilder$processFiles$2$newProviders$1.invokeSuspend(EditorsSplitters.kt:960)
# 				-[x4 of] "editor provider computing":DeferredCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, editor provider computing, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@3f76d0cb, Dispatchers.Default]
# 					at com.intellij.openapi.application.rw.InternalReadAction.readLoop(InternalReadAction.kt:63)
# 					at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$4.invokeSuspend(InternalReadAction.kt:44)
# 					at com.intellij.openapi.fileEditor.impl.FileEditorProviderManagerImplKt.getProviderIfApplicable(FileEditorProviderManagerImpl.kt:188)
# 					at com.intellij.openapi.fileEditor.impl.FileEditorProviderManagerImpl$getProvidersAsync$sharedProviders$1$1$1$2.invokeSuspend(FileEditorProviderManagerImpl.kt:107)
# 					at com.intellij.openapi.fileEditor.impl.FileEditorProviderManagerImpl$getProvidersAsync$sharedProviders$1$1$1.invokeSuspend(FileEditorProviderManagerImpl.kt:106)
# 	- "Application":supervisor:ChildScope{Active}
# 		- "ApplicationImpl@1010884530 container":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.editorconfig.editorconfigjetbrains)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x hg4idea)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.ae.database)":supervisor:ChildScope{Active}
# 				- "com.intellij.ae.database.core.baseEvents.fus.FusEventCatcherService":supervisor:ChildScope{Active}
# 					- "com.intellij.ae.database.core.baseEvents.fus.FusEventCatcherService":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 						at com.intellij.ae.database.core.baseEvents.fus.FusEventCatcherService$1.invokeSuspend(FusEventCatcherService.kt:43)
# 			- "(ApplicationImpl@1010884530 x com.intellij.diagram)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x intellij.grid.core.impl)":supervisor:ChildScope{Active}
# 			-[x2 of] "(ApplicationImpl@1010884530 x com.intellij)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.searcheverywhere.ml)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.settingsSync)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.apacheConfig)":supervisor:ChildScope{Active}
# 			-[x2 of] "(ApplicationImpl@1010884530 x com.jetbrains.space)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x intellij.charts)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.configurationScript)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x Subversion)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.textmate)":supervisor:ChildScope{Active}
# 				- "org.jetbrains.plugins.textmate.TextMateServiceImpl":supervisor:ChildScope{Active}
# 					- "org.jetbrains.plugins.textmate.TextMateServiceImpl":StandaloneCoroutine{Completing} [UnlimitedIoScheduler@46992c56]
# 						- "org.jetbrains.plugins.textmate.TextMateServiceImpl":StandaloneCoroutine{Active}, state: RUNNING [UnlimitedIoScheduler@46992c56]
# 							at java.base@17.0.10/java.util.HashMap.putVal(HashMap.java:629)
# 							at java.base@17.0.10/java.util.HashMap.put(HashMap.java:610)
# 							at com.fasterxml.jackson.databind.deser.std.UntypedObjectDeserializerNR$Scope.putValue(UntypedObjectDeserializerNR.java:517)
# 							at com.fasterxml.jackson.databind.deser.std.UntypedObjectDeserializerNR._deserializeNR(UntypedObjectDeserializerNR.java:270)
# 							at com.fasterxml.jackson.databind.deser.std.UntypedObjectDeserializerNR.deserialize(UntypedObjectDeserializerNR.java:70)
# 							at com.fasterxml.jackson.databind.deser.DefaultDeserializationContext.readRootValue(DefaultDeserializationContext.java:323)
# 							at com.fasterxml.jackson.databind.ObjectMapper._readMapAndClose(ObjectMapper.java:4825)
# 							at com.fasterxml.jackson.databind.ObjectMapper.readValue(ObjectMapper.java:3785)
# 							at org.jetbrains.plugins.textmate.plist.JsonPlistReader.read(JsonPlistReader.java:23)
# 							at org.jetbrains.plugins.textmate.plist.CompositePlistReader.read(CompositePlistReader.java:23)
# 							at org.jetbrains.plugins.textmate.bundles.BundleReaderKt.readPlist(BundleReader.kt:174)
# 							at org.jetbrains.plugins.textmate.bundles.VSCBundleReader$readGrammars$1$plist$1.invoke(VSCBundleReader.kt:61)
# 							at org.jetbrains.plugins.textmate.bundles.VSCBundleReader$readGrammars$1$plist$1.invoke(VSCBundleReader.kt:60)
# 							at kotlin.SynchronizedLazyImpl.getValue(LazyJVM.kt:74)
# 							at org.jetbrains.plugins.textmate.TextMateServiceImpl.registerLanguageSupport(TextMateServiceImpl.java:336)
# 							at org.jetbrains.plugins.textmate.TextMateServiceImpl.registerBundle(TextMateServiceImpl.java:282)
# 							at org.jetbrains.plugins.textmate.TextMateServiceImpl.lambda$registerBundles$1(TextMateServiceImpl.java:100)
# 							at org.jetbrains.plugins.textmate.TextMateServiceImpl$$Lambda$2758/0x0000000101760268.invoke(Unknown Source)
# 							at org.jetbrains.plugins.textmate.TextMateBundlesLoader$registerBundlesInParallel$initializationJob$1$1$1.invokeSuspend(bundlesLoader.kt:36)
# 			- "(ApplicationImpl@1010884530 x com.intellij.platform.images)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.copyright)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.css)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.intellij.plugins.markdown)":supervisor:ChildScope{Active}
# 			-[x2 of] "(ApplicationImpl@1010884530 x org.jetbrains.plugins.terminal)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.sh)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x intellij.platform.ijent.impl)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.rest)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x intellij.indexing.shared.core)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.restClient)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x intellij.grid.impl)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x XPathView)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.tasks)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.intellij.intelliLang)":supervisor:ChildScope{Active}
# 			-[x4 of] "(ApplicationImpl@1010884530 x Docker)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x tanvd.grazi)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x Git4Idea)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.github)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x JavaScript)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x (ApplicationImpl@1010884530 x JavaScript))":supervisor:ChildScope{Active}
# 					- "com.intellij.lang.javascript.service.ide.JSLanguageServiceFileEditorListener":supervisor:ChildScope{Active}
# 						- "com.intellij.lang.javascript.service.ide.JSLanguageServiceFileEditorListener":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 							at com.intellij.lang.javascript.service.ide.JSLanguageServiceEditorListenerBase$1.invokeSuspend(JSLanguageServiceEditorListenerBase.kt:24)
# 			- "(ApplicationImpl@1010884530 x JavaScriptDebugger)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.php)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.twig)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.php.psalm)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.php.tools.quality.phpstan)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.intellij.qodana)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.intellij.database)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x NodeJS)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.node-remote-interpreter)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active}
# 				- "com.jetbrains.rdserver.unattendedHost.UnattendedHostManager":supervisor:ChildScope{Active}
# 				- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active}
# 					- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active}
# 						- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 							at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2.invokeSuspend(ActionManagerImpl.kt:1314)
# 							- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 								- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2$1.invokeSuspend(ActionManagerImpl.kt:1318)
# 				- "com.intellij.remoteDev.tests.impl.DistributedTestHost":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.gateway)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x com.jetbrains.gateway.terminal)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.docker.gateway)":supervisor:ChildScope{Active}
# 			- "(ApplicationImpl@1010884530 x AngularJS)":supervisor:ChildScope{Active}
# 			- "ApplicationImpl@1010884530 container":supervisor:ChildScope{Active}
# 				- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active} [Dispatchers.Default]
# 			- "com.intellij.ide.ui.laf.LafManagerImpl":supervisor:ChildScope{Active}
# 			- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":supervisor:ChildScope{Active}
# 				- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents$1.invokeSuspend(FeatureUsageSettingsEvents.kt:68)
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.ide.plugins.BundledPluginsState$execute$2.invokeSuspend(BundledPluginsState.kt:54)
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.openapi.vfs.newvfs.persistent.VFSHealthCheckServiceStarter$execute$2.invokeSuspend(VFSHealthChecker.kt:82)
# 			- "auto-save icon cache":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.ide.ui.IconDbMaintainer$execute$2.invokeSuspend(IconDbMaintainer.kt:26)
# 			- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":supervisor:ChildScope{Active}
# 				- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":supervisor:ChildScope{Active}
# 			- "com.intellij.openapi.vfs.newvfs.persistent.ExecuteOnCoroutine":supervisor:ChildScope{Active}
# 				- "PersistentFsLoader":supervisor:ChildScope{Active} [Dispatchers.IO]
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.ide.Y.L.invokeSuspend(EvaluationSupportHelper.kt)
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.ide.Y.F.invokeSuspend(AiAgreementUpdateScheduler.kt)
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.ide.AgreementUpdater$execute$2.invokeSuspend(AgreementUpdater.kt:23)
# 			- "com.intellij.ide.ui.laf.LafDynamicPluginManager":supervisor:ChildScope{Active}
# 			- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":supervisor:ChildScope{Active}
# 				- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.ide.ui.html.GlobalStyleSheetUpdateService$init$2.invokeSuspend(GlobalStyleSheetHolder.kt:102)
# 					- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:431)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:426)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:51)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 						- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 			- "com.intellij.history.integration.LocalHistoryImpl":supervisor:ChildScope{Active}
# 				- "com.intellij.history.integration.LocalHistoryImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.history.integration.LocalHistoryImpl$init$3.invokeSuspend(LocalHistoryImpl.kt:94)
# 			- "com.intellij.ide.ui.customization.CustomActionsSchema":supervisor:ChildScope{Active}
# 			- "ApplicationImpl@1010884530 container":ChildScope{Active}
# 			- "com.intellij.diagnostic.PerformanceWatcherImpl":supervisor:ChildScope{Active}
# 				- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.diagnostic.PerformanceWatcherImpl$1.invokeSuspend(PerformanceWatcherImpl.kt:90)
# 					- "com.intellij.diagnostic.PerformanceWatcherImpl":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 						- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 							at com.intellij.diagnostic.PerformanceWatcherImpl$1$1.invokeSuspend(PerformanceWatcherImpl.kt:95)
# 			- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Completing} [Dispatchers.Default]
# 				- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.checkPreviousExternalUploadResult(StatisticsJobsScheduler.kt:72)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$2.invokeSuspend(StatisticsJobsScheduler.kt:39)
# 				- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.runEventLogStatisticsService(StatisticsJobsScheduler.kt:78)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$3.invokeSuspend(StatisticsJobsScheduler.kt:42)
# 				- "ApplicationImpl@1010884530 container":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.runValidationRulesUpdate(StatisticsJobsScheduler.kt:53)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$4.invokeSuspend(StatisticsJobsScheduler.kt:45)
# 			- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":supervisor:ChildScope{Active}
# 				- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger.logApplicationStateRegularly(FUStateUsagesLogger.kt:154)
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger$1.invokeSuspend(FUStateUsagesLogger.kt:53)
# 			- "com.intellij.ide.IdeTooltipManager":supervisor:ChildScope{Active}
# 			- "com.intellij.platform.ide.CoreUiCoroutineScopeHolder":supervisor:ChildScope{Active}
# 				- "com.intellij.platform.ide.CoreUiCoroutineScopeHolder":supervisor:ChildScope{Active}
# 					- "com.intellij.platform.ide.CoreUiCoroutineScopeHolder":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:431)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:426)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:51)
# 						at com.intellij.ui.BalloonLayoutImpl$1.invokeSuspend(BalloonLayoutImpl.kt:75)
# 						- "com.intellij.platform.ide.CoreUiCoroutineScopeHolder":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				-[x3 of] "computeOnEdt (MainToolbar)":DeferredCoroutine{Active}, state: CREATED [ANY, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.EDT]
# 				- "computeOnEdt (ToolwindowTitle)":DeferredCoroutine{Active}, state: CREATED [ANY, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.EDT]
# 				- "computeOnEdt (TabsMoreToolbar)":DeferredCoroutine{Active}, state: CREATED [ANY, kotlinx.coroutines.UndispatchedMarker@22aa5aa0, Dispatchers.EDT]
# 			- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":supervisor:ChildScope{Active}
# 				- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.ide.RecentProjectsManagerBase$1.invokeSuspend(RecentProjectsManagerBase.kt:107)
# 					- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:431)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:426)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:51)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 						- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 			- "com.intellij.ide.actionMacro.ActionMacroManager":supervisor:ChildScope{Active}
# 			- "com.intellij.ide.plugins.marketplace.MarketplaceRequests":supervisor:ChildScope{Active}
# 			- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":supervisor:ChildScope{Active}
# 				- "refresh requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ModalityState.NON_MODAL, Dispatchers.Default]
# 					at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:431)
# 					at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:426)
# 					at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:51)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$1.invokeSuspend(SaveAndSyncHandlerImpl.kt:76)
# 					- "refresh requests flow processing":ProducerCoroutine{Active}, state: SUSPENDED [ModalityState.NON_MODAL, Dispatchers.Default]
# 				- "save requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$2.invokeSuspend(SaveAndSyncHandlerImpl.kt:91)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl.listenIdleAndActivate(SaveAndSyncHandlerImpl.kt:173)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$3.invokeSuspend(SaveAndSyncHandlerImpl.kt:118)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.util.CoroutinesKt$awaitCancellationAndInvoke$1.invokeSuspend(coroutines.kt:27)
# 			- "(ApplicationImpl@1010884530 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active}
# 			- "com.intellij.openapi.progress.impl.PlatformTaskSupport":supervisor:ChildScope{Active}
# 			- "com.intellij.ide.ScreenReaderStateManager":supervisor:ChildScope{Active}
# 				- "com.intellij.ide.ScreenReaderStateManager":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 					at com.intellij.ide.ScreenReaderStateManager$1.invokeSuspend(ScreenReaderStateManager.kt:18)
# 			- "com.intellij.util.indexing.FileBasedIndexImpl":supervisor:ChildScope{Active}
# 			- "org.jetbrains.ide.BuiltInServerManagerImpl":supervisor:ChildScope{Active}
# 			- "ProjectImpl@1058727301 container":supervisor:ChildScope{Active}
# 				- "ProjectImpl@1058727301 container":ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.editorconfig.editorconfigjetbrains)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x hg4idea)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.diagram)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.jetbrains.performancePlugin)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.apacheConfig)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.configurationScript)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x Subversion)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.platform.images)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.copyright)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.css)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.terminal)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.jetbrains.sh)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x name.kropp.intellij.makefile)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x intellij.indexing.shared.core)":supervisor:ChildScope{Active}
# 					- "com.intellij.indexing.shared.download.ShadeIndexDumbModeTracker":supervisor:ChildScope{Active}
# 						- "com.intellij.indexing.shared.download.ShadeIndexDumbModeTracker":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 							at com.intellij.indexing.shared.download.ShadeIndexDumbModeTracker$exitDumbMode$1.invokeSuspend(SharedIndexDumbModeTracking.kt:37)
# 				- "(ProjectImpl@1058727301 x com.jetbrains.restClient)":supervisor:ChildScope{Active}
# 					- "com.intellij.httpClient.http.request.run.v2.HttpRequestRunLineMarkerV2EnablingListener":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.swagger)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x intellij.grid.impl)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x XPathView)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.tasks)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x com.intellij.tasks.timeTracking)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.intellij.intelliLang)":supervisor:ChildScope{Active}
# 				-[x2 of] "(ProjectImpl@1058727301 x Docker)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x PerforceDirectPlugin)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x Git4Idea)":supervisor:ChildScope{Active}
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active}
# 					- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.GitLabMergeRequestsToolWindowController":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.GitLabMergeRequestsToolWindowController":supervisor:ChildScope{Active} [Dispatchers.EDT]
# 					- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active} [Dispatchers.Default]
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 								- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 									- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped$1$1.invokeSuspend(CoroutineUtil.kt:137)
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped$1.invokeSuspend(CoroutineUtil.kt:135)
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 								- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 									- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped$1$1.invokeSuspend(CoroutineUtil.kt:137)
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped$1.invokeSuspend(CoroutineUtil.kt:135)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active} [Dispatchers.EDT]
# 											-[x3 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 												-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: CREATED [Dispatchers.EDT]
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 												- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":ProducerCoroutine{Active}, state: CREATED [Dispatchers.EDT]
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 												-[x3 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: CREATED [Dispatchers.EDT]
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 											at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 											at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 											-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 											at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 											at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 											-[x3 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 											at org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabRepositoryAndAccountSelectorViewModel$1.invokeSuspend(GitLabRepositoryAndAccountSelectorViewModel.kt:43)
# 							-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 								at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 								at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 								at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 								-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 					- "org.jetbrains.plugins.gitlab.api.GitLabProjectConnectionManager":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.gitlab.api.GitLabProjectConnectionManager":supervisor:ChildScope{Active} [Dispatchers.Default]
# 							- "org.jetbrains.plugins.gitlab.api.GitLabProjectConnectionManager":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at git4idea.remote.hosting.SingleHostedGitRepositoryConnectionManagerImpl$1.invokeSuspend(SingleHostedGitRepositoryConnectionManager.kt:50)
# 								- "org.jetbrains.plugins.gitlab.api.GitLabProjectConnectionManager":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 					- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 							at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 							at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 							at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 							at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
# 							- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 								- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at git4idea.remote.hosting.GitAsyncExtensionsKt$gitRemotesFlow$1.invokeSuspend(gitAsyncExtensions.kt:39)
# 							- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 								at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 								at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 								at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 								at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 								- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 								- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 									at kotlinx.coroutines.flow.FlowKt__TransformKt$runningFold$$inlined$unsafeFlow$1.collect(Transform.kt:116)
# 									at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 									- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 										at git4idea.remote.hosting.GitAsyncExtensionsKt$discoverServers$1.invokeSuspend(gitAsyncExtensions.kt:79)
# 										- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 											at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 											- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 												- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 													at git4idea.remote.hosting.GitAsyncExtensionsKt$gitRemotesFlow$1.invokeSuspend(gitAsyncExtensions.kt:39)
# 											- "org.jetbrains.plugins.gitlab.GitLabProjectsManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 					- "org.jetbrains.plugins.gitlab.mergerequest.ui.editor.GitLabMergeRequestEditorReviewController":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.gitlab.mergerequest.ui.editor.GitLabMergeRequestEditorReviewController":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 							at org.jetbrains.plugins.gitlab.mergerequest.ui.editor.GitLabMergeRequestEditorReviewController$setupReview$1.invokeSuspend(GitLabMergeRequestEditorReviewController.kt:50)
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.editor.GitLabMergeRequestEditorReviewController":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 								at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 								- "org.jetbrains.plugins.gitlab.mergerequest.ui.editor.GitLabMergeRequestEditorReviewController":ProducerCoroutine{Active}, state: CREATED [Dispatchers.EDT]
# 				- "(ProjectImpl@1058727301 x org.jetbrains.plugins.github)":supervisor:ChildScope{Active}
# 					- "org.jetbrains.plugins.github.pullrequest.ui.toolwindow.GHPRToolWindowController":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.github.pullrequest.ui.toolwindow.GHPRToolWindowController":supervisor:ChildScope{Active} [Dispatchers.EDT]
# 					- "org.jetbrains.plugins.github.pullrequest.ui.toolwindow.model.GHPRToolWindowViewModel":supervisor:ChildScope{Active}
# 						- "org.jetbrains.plugins.github.pullrequest.ui.toolwindow.model.GHPRToolWindowViewModel":supervisor:ChildScope{Active} [Dispatchers.EDT]
# ...
# 				at com.intellij.openapi.wm.impl.status.InfoAndProgressPanel$5.invokeSuspend(InfoAndProgressPanel.kt:167)
# 			- "IdeRootPane":StandaloneCoroutine{Active}, state: SUSPENDED [ANY, Dispatchers.EDT]
# 				at com.intellij.util.ui.Animator$resume$1.invokeSuspend(Animator.kt:123)
# 	- "IdeRootPane":StandaloneCoroutine{Active}, state: SUSPENDED [ANY, Dispatchers.Default]
# 		at com.intellij.openapi.wm.impl.IdeRootPane$installNorthComponents$2.invokeSuspend(IdeRootPane.kt:649)
# 		- "IdeRootPane":ProducerCoroutine{Active}, state: SUSPENDED [ANY, Dispatchers.Default]
# 			- "IdeRootPane":ProducerCoroutine{Active}, state: SUSPENDED [ANY, Dispatchers.Default]
# 				at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension$component$1.invokeSuspend(NavBarRootPaneExtension.kt:80)
#
# - "FileTypeIndex change notificator":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.psi.search.FileTypeIndexChangeNotifier$worker$1.invokeSuspend(FileTypeIndexChangeNotifier.kt:22)
# 	- "FileTypeIndex change notificator":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 		at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 		- "FileTypeIndex change notificator":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 			at com.intellij.util.flow.FlowKt$throttle$1.invokeSuspend(flow.kt:46)
# 			- "FileTypeIndex change notificator":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at com.intellij.util.flow.FlowKt$throttle$1$latchJob$1.invokeSuspend(flow.kt:41)
# 			- "FileTypeIndex change notificator":ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 				at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
#
# - StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 	at com.intellij.ide.navbar.ui.StaticNavBarPanel$1.invokeSuspend(StaticNavBarPanel.kt:95)
# 	- ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 		at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 		- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 			at com.intellij.ide.navbar.ui.StaticNavBarPanel$handleVm$2.invokeSuspend(StaticNavBarPanel.kt:107)
# 			at com.intellij.ide.navbar.ui.StaticNavBarPanel.handleVm(StaticNavBarPanel.kt:103)
# 			at com.intellij.ide.navbar.ui.StaticNavBarPanel$1$1.invokeSuspend(StaticNavBarPanel.kt:97)
# 			- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 				at com.intellij.ide.navbar.ui.NewNavBarPanel$2.invokeSuspend(NewNavBarPanel.kt:86)
# 				- ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 					at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 					- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 						at com.intellij.ide.navbar.ui.NewNavBarPanel$handleItems$2$1.invokeSuspend(NewNavBarPanel.kt:97)
# 						at com.intellij.ide.navbar.ui.NewNavBarPanel$handleItems$2.invokeSuspend(NewNavBarPanel.kt:93)
# 						- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 							at com.intellij.ide.navbar.ui.NavBarItemComponent$1.invokeSuspend(NavBarItemComponent.kt:76)
# 						- ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 							at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
#
# - StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.ide.navbar.ui.StaticNavBarPanelKt$staticNavBarPanel$1.invokeSuspend(StaticNavBarPanel.kt:67)
# 	- ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 		at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 		- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 			at com.intellij.ide.navbar.ui.StaticNavBarPanelKt$staticNavBarPanel$1$1.invokeSuspend(StaticNavBarPanel.kt:69)
# 			- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 				at com.intellij.ide.navbar.ui.StaticNavBarPanelKt$staticNavBarPanel$handleWindow$2.invokeSuspend(StaticNavBarPanel.kt:57)
# 				at com.intellij.ide.navbar.ui.StaticNavBarPanelKt.staticNavBarPanel$handleWindow(StaticNavBarPanel.kt:48)
# 				at com.intellij.ide.navbar.ui.StaticNavBarPanelKt$staticNavBarPanel$1$1$1$1.invokeSuspend(StaticNavBarPanel.kt:73)
# 				- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 					at com.intellij.ide.navbar.ide.NavBarVmImpl$1.invokeSuspend(NavBarVmImpl.kt:42)
# 					- "com.intellij.ide.navbar.ide.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 						- "com.intellij.ide.navbar.ide.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 							at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 							- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 								at com.intellij.ide.navbar.ui.StaticNavBarPanelKt$staticNavBarPanel$contextItems$1.invokeSuspend(StaticNavBarPanel.kt:42)
# 				- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 					at com.intellij.ide.navbar.ide.NavBarVmImpl$2.invokeSuspend(NavBarVmImpl.kt:52)
# 					- "com.intellij.ide.navbar.ide.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 						- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 							at com.intellij.util.flow.FlowKt$zipWithNext$1.invokeSuspend(flow.kt:107)
# 							at kotlinx.coroutines.flow.AbstractFlow.collect(Flow.kt:230)
# 							at com.intellij.ide.navbar.ide.NavBarVmImpl$handleSelectionChange$2.invokeSuspend(NavBarVmImpl.kt:116)
# 				- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 					at com.intellij.ide.navbar.ide.NavBarVmImpl$3.invokeSuspend(NavBarVmImpl.kt:55)
# 					- "com.intellij.ide.navbar.ide.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:27)
# 				- "com.intellij.ide.navbar.ide.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [LimitedDispatcher@7989bc8a]
# 					at kotlinx.coroutines.flow.FlowKt__CollectKt$launchIn$1.invokeSuspend(Collect.kt:50)
#
# - SupervisorJobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [ANY, Dispatchers.EDT]
# 		at com.intellij.util.ui.Animator$resume$1.invokeSuspend(Animator.kt:123)
#
# - JobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@70829b9b, libraries.klogging.MDCContext@4d0a4d50, circlet.platform.tracing.CoroutineTracingContextElement@364b9de5, libraries.coroutines.extra.LifetimeContextElement@35f51e29, Dispatchers.IO]
# 		at com.intellij.space.components.SpaceConnectionApi$1.invokeSuspend(SpaceConnectionApi.kt:30)
#
# - JobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@70829b9b, libraries.klogging.MDCContext@51cf154f, circlet.platform.tracing.CoroutineTracingContextElement@4e30a2eb, libraries.coroutines.extra.LifetimeContextElement@247eba7d, Dispatchers.IO]
# 		at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3056)
# 		at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 		at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:54)
# 		at com.intellij.space.components.SpaceConnectionApi$2.invokeSuspend(SpaceConnectionApi.kt:85)
# 		- StandaloneCoroutine{Active}, state: SUSPENDED [runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@70829b9b, libraries.klogging.MDCContext@3967fc8d, circlet.platform.tracing.CoroutineTracingContextElement@10abe383, libraries.coroutines.extra.LifetimeContextElement@247eba7d, Dispatchers.IO]
# 			at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
# 		- StandaloneCoroutine{Active}, state: SUSPENDED [runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@70829b9b, libraries.klogging.MDCContext@5b473c87, circlet.platform.tracing.CoroutineTracingContextElement@abbd8c0, libraries.coroutines.extra.LifetimeContextElement@247eba7d, Dispatchers.IO]
# 			at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:31)
#
# - JobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [ANY, runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@cbede8e, libraries.klogging.MDCContext@43469361, circlet.platform.tracing.CoroutineTracingContextElement@21073c8a, libraries.coroutines.extra.LifetimeContextElement@752e8db2, Dispatchers.EDT]
# 		at com.intellij.space.vcs.SpaceProjectContext$2.invokeSuspend(SpaceProjectContext.kt:97)
# 		- ProducerCoroutine{Active}, state: CREATED [ANY, runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@cbede8e, libraries.klogging.MDCContext@f9e7737, circlet.platform.tracing.CoroutineTracingContextElement@7834303e, libraries.coroutines.extra.LifetimeContextElement@752e8db2, Dispatchers.EDT]
#
# - SupervisorJobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 		at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:214)
#
# -[x2 of] StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.ide.Q.z.invokeSuspend(helper.kt)
#
# - JobImpl{Active}
# 	- StandaloneCoroutine{Active}, state: SUSPENDED [runtime.CoroutineExceptionLogger$create$$inlined$CoroutineExceptionHandler$1@70829b9b, libraries.klogging.MDCContext@604fb0de, circlet.platform.tracing.CoroutineTracingContextElement@618df278, libraries.coroutines.extra.LifetimeContextElement@1d5616b1, Dispatchers.IO]
# 		at com.intellij.space.vcs.SpaceProjectContext$3$2$1.invokeSuspend(SpaceProjectContext.kt:118)
#
# 2024-04-03 17:52:18,093 [  14255]   WARN - #c.i.o.a.i.ActionUpdater - 1582 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-04-03 17:52:19,588 [  15750]   WARN - #c.i.o.a.i.ActionUpdater - 1206 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#Update@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction)
# 2024-04-03 17:52:19,628 [  15790]   WARN - #c.i.o.a.i.ActionUpdater - 1254 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#Update@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction)
# 2024-04-03 17:52:21,803 [  17965]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:270)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:102)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-04-03 17:52:21,845 [  18007]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:270)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:102)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-04-03 17:52:21,914 [  18076]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-04-03 17:52:23,021 [  19183]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.database.console.session.DatabaseSessionManager initializer requests com.intellij.database.console.session.DatabaseSessionViewService instance
# 2024-04-03 17:53:07,288 [  63450]   WARN - #c.i.u.x.Binding - no accessors for com.intellij.ide.util.TipsUsageManager$State
